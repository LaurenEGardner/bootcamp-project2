# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine("sqlite:///Resources/data/importexport.db", echo=True)
conn = engine.connect()
# Out:
# 2021-02-08 22:05:00,426 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-02-08 22:05:00,427 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:00,429 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-02-08 22:05:00,430 INFO sqlalchemy.engine.base.Engine ()

# %%
# COVID Data into DB
conn.execute(""" DROP TABLE IF EXISTS covid2020 """)
# Out:
# 2021-02-08 22:05:01,588 INFO sqlalchemy.engine.base.Engine  DROP TABLE IF EXISTS covid2020
# 2021-02-08 22:05:01,590 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:01,600 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# Create covid 2020 table - note that if we use automap_base, the table must have primary key!
conn.execute("""
    CREATE TABLE IF NOT EXISTS covid2020 (
    ID INT PRIMARY KEY,
    day DATE,
    state VARCHAR,
    fips INT,
    cases INT,
    deaths INT,
    year INT,
    month INT
    )
""")
# Out:
# 2021-02-08 22:05:02,573 INFO sqlalchemy.engine.base.Engine
#     CREATE TABLE IF NOT EXISTS covid2020 (
#     ID INT PRIMARY KEY,
#     day DATE,
#     state VARCHAR,
#     fips INT,
#     cases INT,
#     deaths INT,
#     year INT,
#     month INT
#     )
#
# 2021-02-08 22:05:02,575 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:02,582 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# read in csv to df
covid2020 = pd.read_csv("Resources/covidData_clean.csv")
covid2020.head()
# Out:
#           day       state  fips  cases  deaths  year  month
# 0  2020-01-31     Arizona     4      1       0  2020      1
# 1  2020-01-31  California     6      3       0  2020      1
# 2  2020-01-31    Illinois    17      2       0  2020      1
# 3  2020-01-31  Washington    53      1       0  2020      1
# 4  2020-02-29     Arizona     4      1       0  2020      2

# %%
conn.execute(""" DROP TABLE IF EXISTS IntLatLng """)
# Out:
# 2021-02-08 22:05:05,295 INFO sqlalchemy.engine.base.Engine  DROP TABLE IF EXISTS IntLatLng
# 2021-02-08 22:05:05,297 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:05,301 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# Create  - note that if we use automap_base, the table must have primary key!
conn.execute("""
    CREATE TABLE IF NOT EXISTS IntLatLng (
    COUNTRY_NAME INT PRIMARY KEY,
    INT_LAT FLOAT( 10, 6 ),
    INT_LNG FLOAT( 10, 6 ),
    INT_LAT_LNG VARCHAR
    )
""")
# Out:
# 2021-02-08 22:05:06,964 INFO sqlalchemy.engine.base.Engine
#     CREATE TABLE IF NOT EXISTS IntLatLng (
#     COUNTRY_NAME INT PRIMARY KEY,
#     INT_LAT FLOAT( 10, 6 ),
#     INT_LNG FLOAT( 10, 6 ),
#     INT_LAT_LNG VARCHAR
#     )
#
# 2021-02-08 22:05:06,966 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:06,974 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# read in csv to df
IntLatLng= pd.read_csv("Resources/international_lat_lng2.csv")
IntLatLng.head()
# Out:
#                       COUNTRY_NAME  INT_LAT   INT_LNG         INT_LAT_LNG
# 0                   EUROPEAN UNION  54.5400   25.1900        54.54, 25.19
# 1            PACIFIC RIM COUNTIRES  12.8797  121.7740    12.8797, 121.774
# 2                            NAFTA  47.1164 -101.2996  47.1164, -101.2996
# 3  TWENTY LATIN AMERICAN REPUBLICS  -4.4420  -61.3269    -4.442, -61.3269
# 4                             OECD  28.8566    2.3522     28.8566, 2.3522

# %%
conn.execute(""" DROP TABLE IF EXISTS usLatLon """)
# Out:
# 2021-02-08 22:05:08,740 INFO sqlalchemy.engine.base.Engine  DROP TABLE IF EXISTS usLatLon
# 2021-02-08 22:05:08,744 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:08,751 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# read in csv to df
usLatLon= pd.read_csv("Resources/zip_Lat_Lon_US2.csv")
usLatLon.head()
# Out:
#    ZIP    US_LAT   US_LONG       CITY STATE_ID        STATE  POPULATION  \
# 0  601  18.18004 -66.75218   Adjuntas       PR  Puerto Rico       17242
# 1  602  18.36073 -67.17517     Aguada       PR  Puerto Rico       38442
# 2  603  18.45439 -67.12202  Aguadilla       PR  Puerto Rico       48814
# 3  606  18.16724 -66.93828    Maricao       PR  Puerto Rico        6437
# 4  610  18.29032 -67.12243     Anasco       PR  Puerto Rico       27073
#
#    COUNTY_FIPS  DISTRICT_NAME                            US_LAT_LONG
# 0        72001   ADJUNTAS, PR  18.180039999999998,-66.75218000000001
# 1        72003     AGUADA, PR                     18.36073,-67.17517
# 2        72005  AGUADILLA, PR            18.45439,-67.12201999999999
# 3        72093    MARICAO, PR                     18.16724,-66.93828
# 4        72011     ANASCO, PR            18.29032,-67.12243000000001

# %%
# Create  - note that if we use automap_base, the table must have primary key!
conn.execute("""
    CREATE TABLE IF NOT EXISTS usLatLon (
    ZIP INT PRIMARY KEY,
    US_LAT DOUBLE,
    US_LONG DOUBLE,
    CITY STR,
    STATE_ID STR,
    STATE STR,
    POPULATION INT,
    COUNTRY_FIPS INT,
    DISTRICT_NAME STR,
    US_LAT_LONG STR
    )
""")
# Out:
# 2021-02-08 22:05:10,549 INFO sqlalchemy.engine.base.Engine
#     CREATE TABLE IF NOT EXISTS usLatLon (
#     ZIP INT PRIMARY KEY,
#     US_LAT DOUBLE,
#     US_LONG DOUBLE,
#     CITY STR,
#     STATE_ID STR,
#     STATE STR,
#     POPULATION INT,
#     COUNTRY_FIPS INT,
#     DISTRICT_NAME STR,
#     US_LAT_LONG STR
#     )
#
# 2021-02-08 22:05:10,551 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:10,562 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
conn.execute(""" DROP TABLE IF EXISTS export2019 """)
# Out:
# 2021-02-08 22:05:11,384 INFO sqlalchemy.engine.base.Engine  DROP TABLE IF EXISTS export2019
# 2021-02-08 22:05:11,391 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:11,405 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# read in csv to df
export2019 = pd.read_csv("Resources/exportData2019.csv")
export2019.head()
#export2019.columns
# Out:
#   COUNTRY_CODE COUNTRY_NAME DOMESTIC_FOREIGN_CODE  DISTRICT   DISTRICT_NAME  \
# 0         0023         NATO                     -         7  OGDENSBURG, NY
# 1         0020        NAFTA                     -         7  OGDENSBURG, NY
# 2         0022         OECD                     -         7  OGDENSBURG, NY
# 3         0026         APEC                     -         7  OGDENSBURG, NY
# 4         1220       CANADA                     -         7  OGDENSBURG, NY
#
#    ALL_VALUES_MONTH  ALL_VALUES_YEAR COMMODITY_DESCRIPTION   COMMODITY  YEAR  \
# 0            267236           267236         ACRYLONITRILE  2926100000  2019
# 1            267236           267236         ACRYLONITRILE  2926100000  2019
# 2            267236           267236         ACRYLONITRILE  2926100000  2019
# 3            267236           267236         ACRYLONITRILE  2926100000  2019
# 4            267236           267236         ACRYLONITRILE  2926100000  2019
#
#    MONTH
# 0      1
# 1      1
# 2      1
# ...

# %%
export2019 = pd.merge(export2019, IntLatLng, how="inner", on="COUNTRY_NAME")
export2019.head()
# Out:
#   COUNTRY_CODE COUNTRY_NAME DOMESTIC_FOREIGN_CODE  DISTRICT  \
# 0         0023         NATO                     -         7
# 1         0023         NATO                     -        20
# 2         0023         NATO                     -        38
# 3         0023         NATO                     -        53
# 4         0023         NATO                     1         7
#
#            DISTRICT_NAME  ALL_VALUES_MONTH  ALL_VALUES_YEAR  \
# 0         OGDENSBURG, NY            267236           267236
# 1        NEW ORLEANS, LA           2496000          2496000
# 2            DETROIT, MI             71346            71346
# 3  HOUSTON-GALVESTON, TX           3869418          3869418
# 4         OGDENSBURG, NY            267236           267236
#
#   COMMODITY_DESCRIPTION   COMMODITY  YEAR  MONTH  INT_LAT  INT_LNG  \
# 0         ACRYLONITRILE  2926100000  2019      1  50.8503   4.3517
# 1         ACRYLONITRILE  2926100000  2019      1  50.8503   4.3517
# ...

# %%
export2019 = export2019[['COUNTRY_CODE', 'COUNTRY_NAME', 'DOMESTIC_FOREIGN_CODE', 'DISTRICT',
       'DISTRICT_NAME', 'ALL_VALUES_MONTH', 'ALL_VALUES_YEAR',
       'COMMODITY_DESCRIPTION', 'COMMODITY', 'YEAR', 'MONTH', 'INT_LAT',
       'INT_LNG', 'INT_LAT_LNG']]
export2019.head()
# Out:
#   COUNTRY_CODE COUNTRY_NAME DOMESTIC_FOREIGN_CODE  DISTRICT  \
# 0         0023         NATO                     -         7
# 1         0023         NATO                     -        20
# 2         0023         NATO                     -        38
# 3         0023         NATO                     -        53
# 4         0023         NATO                     1         7
#
#            DISTRICT_NAME  ALL_VALUES_MONTH  ALL_VALUES_YEAR  \
# 0         OGDENSBURG, NY            267236           267236
# 1        NEW ORLEANS, LA           2496000          2496000
# 2            DETROIT, MI             71346            71346
# 3  HOUSTON-GALVESTON, TX           3869418          3869418
# 4         OGDENSBURG, NY            267236           267236
#
#   COMMODITY_DESCRIPTION   COMMODITY  YEAR  MONTH  INT_LAT  INT_LNG  \
# 0         ACRYLONITRILE  2926100000  2019      1  50.8503   4.3517
# 1         ACRYLONITRILE  2926100000  2019      1  50.8503   4.3517
# ...

# %%
export2019 = pd.merge(export2019, usLatLon, how="inner", on="DISTRICT_NAME")
export2019.head()
# Out:
#   COUNTRY_CODE COUNTRY_NAME DOMESTIC_FOREIGN_CODE  DISTRICT   DISTRICT_NAME  \
# 0         0023         NATO                     -         7  OGDENSBURG, NY
# 1         0023         NATO                     1         7  OGDENSBURG, NY
# 2         0023         NATO                     -         7  OGDENSBURG, NY
# 3         0023         NATO                     1         7  OGDENSBURG, NY
# 4         0023         NATO                     -         7  OGDENSBURG, NY
#
#    ALL_VALUES_MONTH  ALL_VALUES_YEAR COMMODITY_DESCRIPTION   COMMODITY  YEAR  \
# 0            267236           267236         ACRYLONITRILE  2926100000  2019
# 1            267236           267236         ACRYLONITRILE  2926100000  2019
# 2            209401           476637         ACRYLONITRILE  2926100000  2019
# 3            209401           476637         ACRYLONITRILE  2926100000  2019
# 4            165865           642502         ACRYLONITRILE  2926100000  2019
#
# ...

# %%
# Create export2019 table - note that if we use automap_base, the table must have primary key!
conn.execute("""
    CREATE TABLE IF NOT EXISTS export2019 (
    ID INT PRIMARY KEY,
    COUNTRY_CODE INT,
    COUNTRY_NAME VARCHAR,
    DOMESTIC_FOREIGN_CODE INT,
    DISTRICT INT,
    DISTRICT_NAME VARCHAR,
    ALL_VALUES_MONTH DOUBLE,
    ALL_VALUES_YEAR DOUBLE,
    COMMODITY_DESCRIPTION VARCHAR,
    COMMODITY INT,
    YEAR INT,
    MONTH INT,
    INT_LAT FLOAT( 10, 6 ),
    INT_LNG FLOAT( 10, 6 ),
    INT_LAT_LNG VARCHAR,
    ZIP INT,
    US_LAT DOUBLE,
    US_LONG DOUBLE,
    CITY STR,
    STATE_ID STR,
    STATE STR,
    POPULATION INT,
    US_LAT_LONG STR
    )
""")
# Out:
# 2021-02-08 22:05:14,966 INFO sqlalchemy.engine.base.Engine
#     CREATE TABLE IF NOT EXISTS export2019 (
#     ID INT PRIMARY KEY,
#     COUNTRY_CODE INT,
#     COUNTRY_NAME VARCHAR,
#     DOMESTIC_FOREIGN_CODE INT,
#     DISTRICT INT,
#     DISTRICT_NAME VARCHAR,
#     ALL_VALUES_MONTH DOUBLE,
#     ALL_VALUES_YEAR DOUBLE,
#     COMMODITY_DESCRIPTION VARCHAR,
#     COMMODITY INT,
#     YEAR INT,
#     MONTH INT,
#     INT_LAT FLOAT( 10, 6 ),
#     INT_LNG FLOAT( 10, 6 ),
#     INT_LAT_LNG VARCHAR,
#     ZIP INT,
#     US_LAT DOUBLE,
#     US_LONG DOUBLE,
#     CITY STR,
#     STATE_ID STR,
#     STATE STR,
#     POPULATION INT,
#     US_LAT_LONG STR
#     )
#
# 2021-02-08 22:05:14,970 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:14,977 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
conn.execute(""" DROP TABLE IF EXISTS export2020 """)
# Out:
# 2021-02-08 22:05:15,646 INFO sqlalchemy.engine.base.Engine  DROP TABLE IF EXISTS export2020
# 2021-02-08 22:05:15,648 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:15,659 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# read in csv to df
export2020 = pd.read_csv("Resources/exportData2020.csv")
export2020.head()
# Out:
#   COUNTRY_CODE COUNTRY_NAME DOMESTIC_FOREIGN_CODE  DISTRICT   DISTRICT_NAME  \
# 0         0020        NAFTA                     -         7  OGDENSBURG, NY
# 1         0022         OECD                     -         7  OGDENSBURG, NY
# 2         0023         NATO                     -         7  OGDENSBURG, NY
# 3         0026         APEC                     -         7  OGDENSBURG, NY
# 4         1220       CANADA                     -         7  OGDENSBURG, NY
#
#    ALL_VALUES_MONTH  ALL_VALUES_YEAR COMMODITY_DESCRIPTION   COMMODITY  YEAR  \
# 0            215368           215368         ACRYLONITRILE  2926100000  2020
# 1            215368           215368         ACRYLONITRILE  2926100000  2020
# 2            215368           215368         ACRYLONITRILE  2926100000  2020
# 3            215368           215368         ACRYLONITRILE  2926100000  2020
# 4            215368           215368         ACRYLONITRILE  2926100000  2020
#
#    MONTH
# 0      1
# 1      1
# 2      1
# ...

# %%
export2020 = pd.merge(export2020, IntLatLng, how="inner", on="COUNTRY_NAME")
export2020.head()
# Out:
#   COUNTRY_CODE COUNTRY_NAME DOMESTIC_FOREIGN_CODE  DISTRICT  \
# 0         0020        NAFTA                     -         7
# 1         0020        NAFTA                     -        23
# 2         0020        NAFTA                     -        38
# 3         0020        NAFTA                     -        53
# 4         0020        NAFTA                     1         7
#
#            DISTRICT_NAME  ALL_VALUES_MONTH  ALL_VALUES_YEAR  \
# 0         OGDENSBURG, NY            215368           215368
# 1             LAREDO, TX             54803            54803
# 2            DETROIT, MI            294333           294333
# 3  HOUSTON-GALVESTON, TX           5783820          5783820
# 4         OGDENSBURG, NY            215368           215368
#
#   COMMODITY_DESCRIPTION   COMMODITY  YEAR  MONTH  INT_LAT   INT_LNG  \
# 0         ACRYLONITRILE  2926100000  2020      1  47.1164 -101.2996
# 1         ACRYLONITRILE  2926100000  2020      1  47.1164 -101.2996
# ...

# %%
export2020 = export2020[['COUNTRY_CODE', 'COUNTRY_NAME', 'DOMESTIC_FOREIGN_CODE', 'DISTRICT',
       'DISTRICT_NAME', 'ALL_VALUES_MONTH', 'ALL_VALUES_YEAR',
       'COMMODITY_DESCRIPTION', 'COMMODITY', 'YEAR', 'MONTH', 'INT_LAT',
       'INT_LNG', 'INT_LAT_LNG']]
export2020.head()

# %%
export2020 = pd.merge(export2020, usLatLon, how="inner", on="DISTRICT_NAME")
export2020.head()
# Out:
#   COUNTRY_CODE COUNTRY_NAME DOMESTIC_FOREIGN_CODE  DISTRICT   DISTRICT_NAME  \
# 0         0020        NAFTA                     -         7  OGDENSBURG, NY
# 1         0020        NAFTA                     1         7  OGDENSBURG, NY
# 2         0020        NAFTA                     1         7  OGDENSBURG, NY
# 3         0020        NAFTA                     -         7  OGDENSBURG, NY
# 4         0020        NAFTA                     -         7  OGDENSBURG, NY
#
#    ALL_VALUES_MONTH  ALL_VALUES_YEAR COMMODITY_DESCRIPTION   COMMODITY  YEAR  \
# 0            215368           215368         ACRYLONITRILE  2926100000  2020
# 1            215368           215368         ACRYLONITRILE  2926100000  2020
# 2            146476           361844         ACRYLONITRILE  2926100000  2020
# 3            146476           361844         ACRYLONITRILE  2926100000  2020
# 4            171585           533429         ACRYLONITRILE  2926100000  2020
#
# ...

# %%
# Create export2020 table - note that if we use automap_base, the table must have primary key!
conn.execute("""
    CREATE TABLE IF NOT EXISTS export2020 (
    ID INT PRIMARY KEY,
    COUNTRY_CODE INT,
    COUNTRY_NAME VARCHAR,
    DOMESTIC_FOREIGN_CODE INT,
    DISTRICT INT,
    DISTRICT_NAME VARCHAR,
    ALL_VALUES_MONTH DOUBLE,
    ALL_VALUES_YEAR DOUBLE,
    COMMODITY_DESCRIPTION VARCHAR,
    COMMODITY INT,
    YEAR INT,
    MONTH INT,
    INT_LAT FLOAT( 10, 6 ),
    INT_LNG FLOAT( 10, 6 ),
    INT_LAT_LNG VARCHAR,
    ZIP INT,
    US_LAT DOUBLE,
    US_LONG DOUBLE,
    CITY STR,
    STATE_ID STR,
    STATE STR,
    POPULATION INT,
    US_LAT_LONG STR
    )
""")
# Out:
# 2021-02-08 22:05:19,069 INFO sqlalchemy.engine.base.Engine
#     CREATE TABLE IF NOT EXISTS export2020 (
#     ID INT PRIMARY KEY,
#     COUNTRY_CODE INT,
#     COUNTRY_NAME VARCHAR,
#     DOMESTIC_FOREIGN_CODE INT,
#     DISTRICT INT,
#     DISTRICT_NAME VARCHAR,
#     ALL_VALUES_MONTH DOUBLE,
#     ALL_VALUES_YEAR DOUBLE,
#     COMMODITY_DESCRIPTION VARCHAR,
#     COMMODITY INT,
#     YEAR INT,
#     MONTH INT,
#     INT_LAT FLOAT( 10, 6 ),
#     INT_LNG FLOAT( 10, 6 ),
#     INT_LAT_LNG VARCHAR,
#     ZIP INT,
#     US_LAT DOUBLE,
#     US_LONG DOUBLE,
#     CITY STR,
#     STATE_ID STR,
#     STATE STR,
#     POPULATION INT,
#     US_LAT_LONG STR
#     )
#
# 2021-02-08 22:05:19,074 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:19,081 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
conn.execute(""" DROP TABLE IF EXISTS import2019 """)
# Out:
# 2021-02-08 22:05:19,613 INFO sqlalchemy.engine.base.Engine  DROP TABLE IF EXISTS import2019
# 2021-02-08 22:05:19,614 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:19,623 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# read in csv to df
import2019 = pd.read_csv("Resources/importData2019.csv")
import2019.head()
# Out:
#   SUMMARY_LEVEL SUMMARY_LEVEL_2 COUNTRY_CODE           COUNTRY_NAME  \
# 0           CGP        HSCYCSDT         0003         EUROPEAN UNION
# 1           CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
# 2           CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
# 3           CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
# 4           CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
#
#   COUNTRY_SUBCODE  GENERAL_VALUES_MONTH  GENERAL_VALUES_YEAR  DISTRICT  \
# 0              00                 86406                86406        41
# 1              00                268698               268698         4
# 2              00                   336                  336         7
# 3              00                   790                  790         9
# 4              00               3801253              3801253        10
#
#        DISTRICT_NAME  MONTHLY_CONSUMPTION_VALUE  YEARLY_CONSUMPTION_VALUE  \
# ...

# %%
#add international lat and lng
import2019 = pd.merge(import2019, IntLatLng, how="inner", on="COUNTRY_NAME")
import2019.head()
#import2019 = import2019[[]]
# Out:
#   SUMMARY_LEVEL SUMMARY_LEVEL_2 COUNTRY_CODE    COUNTRY_NAME COUNTRY_SUBCODE  \
# 0           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 1           CGP          HSCYDT         0003  EUROPEAN UNION               -
# 2           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 3           CGP          HSCYDT         0003  EUROPEAN UNION               -
# 4           CGP          HSCYDT         0003  EUROPEAN UNION               -
#
#    GENERAL_VALUES_MONTH  GENERAL_VALUES_YEAR  DISTRICT  DISTRICT_NAME  \
# 0                 86406                86406        41  CLEVELAND, OH
# 1                 86406                86406        41  CLEVELAND, OH
# 2                     0                86406        41  CLEVELAND, OH
# 3                     0                86406        41  CLEVELAND, OH
# 4                207044               293450        41  CLEVELAND, OH
#
#    MONTHLY_CONSUMPTION_VALUE  YEARLY_CONSUMPTION_VALUE  \
# ...

# %%
import2019 = import2019[['SUMMARY_LEVEL', 'SUMMARY_LEVEL_2', 'COUNTRY_CODE', 'COUNTRY_NAME',
       'COUNTRY_SUBCODE', 'GENERAL_VALUES_MONTH', 'GENERAL_VALUES_YEAR',
       'DISTRICT', 'DISTRICT_NAME', 'MONTHLY_CONSUMPTION_VALUE',
       'YEARLY_CONSUMPTION_VALUE', 'COMMODITY_DESCRIPTION', 'COMMODITY',
       'YEAR', 'MONTH', 'INT_LAT', 'INT_LNG', 'INT_LAT_LNG']]
import2019.head()
# Out:
#   SUMMARY_LEVEL SUMMARY_LEVEL_2 COUNTRY_CODE    COUNTRY_NAME COUNTRY_SUBCODE  \
# 0           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 1           CGP          HSCYDT         0003  EUROPEAN UNION               -
# 2           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 3           CGP          HSCYDT         0003  EUROPEAN UNION               -
# 4           CGP          HSCYDT         0003  EUROPEAN UNION               -
#
#    GENERAL_VALUES_MONTH  GENERAL_VALUES_YEAR  DISTRICT  DISTRICT_NAME  \
# 0                 86406                86406        41  CLEVELAND, OH
# 1                 86406                86406        41  CLEVELAND, OH
# 2                     0                86406        41  CLEVELAND, OH
# 3                     0                86406        41  CLEVELAND, OH
# 4                207044               293450        41  CLEVELAND, OH
#
#    MONTHLY_CONSUMPTION_VALUE  YEARLY_CONSUMPTION_VALUE  \
# ...

# %%
import2019 = pd.merge(import2019, usLatLon, how="inner", on="DISTRICT_NAME")
import2019.head()
# Out:
#   SUMMARY_LEVEL SUMMARY_LEVEL_2 COUNTRY_CODE    COUNTRY_NAME COUNTRY_SUBCODE  \
# 0           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 1           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 2           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 3           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 4           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
#
#    GENERAL_VALUES_MONTH  GENERAL_VALUES_YEAR  DISTRICT  DISTRICT_NAME  \
# 0                 86406                86406        41  CLEVELAND, OH
# 1                 86406                86406        41  CLEVELAND, OH
# 2                 86406                86406        41  CLEVELAND, OH
# 3                 86406                86406        41  CLEVELAND, OH
# 4                 86406                86406        41  CLEVELAND, OH
#
#    MONTHLY_CONSUMPTION_VALUE  ...   INT_LAT_LNG    ZIP    US_LAT   US_LONG  \
# ...

# %%
# Create import2019 table - note that if we use automap_base, the table must have primary key!
conn.execute("""
    CREATE TABLE IF NOT EXISTS import2019 (
    ID INT PRIMARY KEY,
    SUMMARY_LEVEL VARCHAR,
    SUMMARY_LEVEL_2 VARCHAR,
    COUNTRY_CODE INT,
    COUNTRY_NAME VARCHAR,
    COUNTRY_SUBCODE INT,
    GENERAL_VALUES_MONTH DOUBLE,
    GENERAL_VALUES_YEAR DOUBLE,
    DISTRICT INT,
    DISTRICT_NAME VARCHAR,
    MONTHLY_CONSUMPTION_VALUE DOUBLE,
    YEARLY_CONSUMPTION_VALUE DOUBLE,
    COMMODITY_DESCRIPTION VARCHAR,
    COMMODITY INT,
    YEAR INT,
    MONTH INT,
    INT_LAT FLOAT( 10, 6 ),
    INT_LNG FLOAT( 10, 6 ),
    INT_LAT_LNG VARCHAR,
    ZIP INT,
    US_LAT DOUBLE,
    US_LONG DOUBLE,
    CITY STR,
    STATE_ID STR,
    STATE STR,
    POPULATION INT,
    US_LAT_LONG STR 
    )
""")
# Out:
# 2021-02-08 22:05:22,357 INFO sqlalchemy.engine.base.Engine
#     CREATE TABLE IF NOT EXISTS import2019 (
#     ID INT PRIMARY KEY,
#     SUMMARY_LEVEL VARCHAR,
#     SUMMARY_LEVEL_2 VARCHAR,
#     COUNTRY_CODE INT,
#     COUNTRY_NAME VARCHAR,
#     COUNTRY_SUBCODE INT,
#     GENERAL_VALUES_MONTH DOUBLE,
#     GENERAL_VALUES_YEAR DOUBLE,
#     DISTRICT INT,
#     DISTRICT_NAME VARCHAR,
#     MONTHLY_CONSUMPTION_VALUE DOUBLE,
#     YEARLY_CONSUMPTION_VALUE DOUBLE,
#     COMMODITY_DESCRIPTION VARCHAR,
#     COMMODITY INT,
#     YEAR INT,
#     MONTH INT,
#     INT_LAT FLOAT( 10, 6 ),
#     INT_LNG FLOAT( 10, 6 ),
#     INT_LAT_LNG VARCHAR,
#     ZIP INT,
#     US_LAT DOUBLE,
#     US_LONG DOUBLE,
#     CITY STR,
#     STATE_ID STR,
#     STATE STR,
#     POPULATION INT,
#     US_LAT_LONG STR
#     )
#
# 2021-02-08 22:05:22,361 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:22,370 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
conn.execute(""" DROP TABLE IF EXISTS import2020 """)
# Out:
# 2021-02-08 22:05:22,845 INFO sqlalchemy.engine.base.Engine  DROP TABLE IF EXISTS import2020
# 2021-02-08 22:05:22,848 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:22,856 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
# read in csv to df
import2020 = pd.read_csv("Resources/importData2020.csv")
import2020.head()
# Out:
#   SUMMARY_LEVEL SUMMARY_LEVEL_2 COUNTRY_CODE           COUNTRY_NAME  \
# 0           CGP        HSCYCSDT         0003         EUROPEAN UNION
# 1           CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
# 2           CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
# 3           CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
# 4           CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
#
#   COUNTRY_SUBCODE  GENERAL_VALUES_MONTH  GENERAL_VALUES_YEAR  DISTRICT  \
# 0              00                106774               106774        41
# 1              00                100359               100359         4
# 2              00               2782365              2782365        10
# 3              00                221603               221603        13
# 4              00                407135               407135        16
#
#        DISTRICT_NAME  MONTHLY_CONSUMPTION_VALUE  YEARLY_CONSUMPTION_VALUE  \
# ...

# %%
import2020 = pd.merge(import2020, IntLatLng, how="inner", on="COUNTRY_NAME")
import2020.head()
# Out:
#   SUMMARY_LEVEL SUMMARY_LEVEL_2 COUNTRY_CODE    COUNTRY_NAME COUNTRY_SUBCODE  \
# 0           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 1           CGP          HSCYDT         0003  EUROPEAN UNION               -
# 2           CGP          HSCYDT         0003  EUROPEAN UNION               -
# 3           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 4           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
#
#    GENERAL_VALUES_MONTH  GENERAL_VALUES_YEAR  DISTRICT      DISTRICT_NAME  \
# 0                106774               106774        41      CLEVELAND, OH
# 1                106774               106774        41      CLEVELAND, OH
# 2                125288               232062        41      CLEVELAND, OH
# 3                125288               232062        41      CLEVELAND, OH
# 4                  1168                 1168        10  NEW YORK CITY, NY
#
#    MONTHLY_CONSUMPTION_VALUE  YEARLY_CONSUMPTION_VALUE  \
# ...

# %%
import2020 = import2020[['SUMMARY_LEVEL', 'SUMMARY_LEVEL_2', 'COUNTRY_CODE', 'COUNTRY_NAME',
       'COUNTRY_SUBCODE', 'GENERAL_VALUES_MONTH', 'GENERAL_VALUES_YEAR',
       'DISTRICT', 'DISTRICT_NAME', 'MONTHLY_CONSUMPTION_VALUE',
       'YEARLY_CONSUMPTION_VALUE', 'COMMODITY_DESCRIPTION', 'COMMODITY',
       'YEAR', 'MONTH', 'INT_LAT', 'INT_LNG', 'INT_LAT_LNG']]
import2020.head()
# Out:
#   SUMMARY_LEVEL SUMMARY_LEVEL_2 COUNTRY_CODE    COUNTRY_NAME COUNTRY_SUBCODE  \
# 0           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 1           CGP          HSCYDT         0003  EUROPEAN UNION               -
# 2           CGP          HSCYDT         0003  EUROPEAN UNION               -
# 3           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 4           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
#
#    GENERAL_VALUES_MONTH  GENERAL_VALUES_YEAR  DISTRICT      DISTRICT_NAME  \
# 0                106774               106774        41      CLEVELAND, OH
# 1                106774               106774        41      CLEVELAND, OH
# 2                125288               232062        41      CLEVELAND, OH
# 3                125288               232062        41      CLEVELAND, OH
# 4                  1168                 1168        10  NEW YORK CITY, NY
#
#    MONTHLY_CONSUMPTION_VALUE  YEARLY_CONSUMPTION_VALUE  \
# ...

# %%
import2020 = pd.merge(import2020, usLatLon, how="inner", on="DISTRICT_NAME")
import2020.head()
# Out:
#   SUMMARY_LEVEL SUMMARY_LEVEL_2 COUNTRY_CODE    COUNTRY_NAME COUNTRY_SUBCODE  \
# 0           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 1           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 2           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 3           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
# 4           CGP        HSCYCSDT         0003  EUROPEAN UNION              00
#
#    GENERAL_VALUES_MONTH  GENERAL_VALUES_YEAR  DISTRICT  DISTRICT_NAME  \
# 0                106774               106774        41  CLEVELAND, OH
# 1                106774               106774        41  CLEVELAND, OH
# 2                106774               106774        41  CLEVELAND, OH
# 3                106774               106774        41  CLEVELAND, OH
# 4                106774               106774        41  CLEVELAND, OH
#
#    MONTHLY_CONSUMPTION_VALUE  ...   INT_LAT_LNG    ZIP    US_LAT   US_LONG  \
# ...

# %%
# Create import2020 table - note that if we use automap_base, the table must have primary key!
conn.execute("""
    CREATE TABLE IF NOT EXISTS import2020 (
    ID INT PRIMARY KEY,
    SUMMARY_LEVEL VARCHAR,
    SUMMARY_LEVEL_2 VARCHAR,
    COUNTRY_CODE INT,
    COUNTRY_NAME VARCHAR,
    COUNTRY_SUBCODE INT,
    GENERAL_VALUES_MONTH DOUBLE,
    GENERAL_VALUES_YEAR DOUBLE,
    DISTRICT INT,
    DISTRICT_NAME VARCHAR,
    MONTHLY_CONSUMPTION_VALUE DOUBLE,
    YEARLY_CONSUMPTION_VALUE DOUBLE,
    COMMODITY_DESCRIPTION VARCHAR,
    COMMODITY INT,
    YEAR INT,
    MONTH INT,
    INT_LAT FLOAT( 10, 6 ),
    INT_LNG FLOAT( 10, 6 ),
    INT_LAT_LNG VARCHAR,
    ZIP INT,
    US_LAT DOUBLE,
    US_LONG DOUBLE,
    CITY STR,
    STATE_ID STR,
    STATE STR,
    POPULATION INT,
    US_LAT_LONG STR
    )
""")
# Out:
# 2021-02-08 22:05:25,502 INFO sqlalchemy.engine.base.Engine
#     CREATE TABLE IF NOT EXISTS import2020 (
#     ID INT PRIMARY KEY,
#     SUMMARY_LEVEL VARCHAR,
#     SUMMARY_LEVEL_2 VARCHAR,
#     COUNTRY_CODE INT,
#     COUNTRY_NAME VARCHAR,
#     COUNTRY_SUBCODE INT,
#     GENERAL_VALUES_MONTH DOUBLE,
#     GENERAL_VALUES_YEAR DOUBLE,
#     DISTRICT INT,
#     DISTRICT_NAME VARCHAR,
#     MONTHLY_CONSUMPTION_VALUE DOUBLE,
#     YEARLY_CONSUMPTION_VALUE DOUBLE,
#     COMMODITY_DESCRIPTION VARCHAR,
#     COMMODITY INT,
#     YEAR INT,
#     MONTH INT,
#     INT_LAT FLOAT( 10, 6 ),
#     INT_LNG FLOAT( 10, 6 ),
#     INT_LAT_LNG VARCHAR,
#     ZIP INT,
#     US_LAT DOUBLE,
#     US_LONG DOUBLE,
#     CITY STR,
#     STATE_ID STR,
#     STATE STR,
#     POPULATION INT,
#     US_LAT_LONG STR
#     )
#
# 2021-02-08 22:05:25,505 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:05:25,513 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
export2019.index.names=["ID"]
export2020.index.names=["ID"]
import2020.index.names=["ID"]
import2019.index.names=["ID"]
covid2020.index.names=["ID"]
IntLatLng.index.names=["ID"]
#usLatLon.index.names=["ID"]

# %%
# insert data into the DB
export2019.to_sql("export2019", conn, if_exists="append")
export2020.to_sql("export2020", conn, if_exists="append")
import2019.to_sql("import2019", conn, if_exists="append")
import2020.to_sql("import2020", conn, if_exists="append")
covid2020.to_sql("covid2020", conn, if_exists="append")
IntLatLng.to_sql("IntLatLng", conn, if_exists="append")
#usLatLon.to_sql("usLatLon", conn, if_exists="append")
# Out:
# 2021-02-08 22:06:01,610 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("export2019")
# 2021-02-08 22:06:01,611 INFO sqlalchemy.engine.base.Engine ()
# 2021-02-08 22:06:03,049 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-02-08 22:07:06,826 INFO sqlalchemy.engine.base.Engine INSERT INTO export2019 ("ID", "COUNTRY_CODE", "COUNTRY_NAME", "DOMESTIC_FOREIGN_CODE", "DISTRICT", "DISTRICT_NAME", "ALL_VALUES_MONTH", "ALL_VALUES_YEAR", "COMMODITY_DESCRIPTION", "COMMODITY", "YEAR", "MONTH", "INT_LAT", "INT_LNG", "INT_LAT_LNG", "ZIP", "US_LAT", "US_LONG", "CITY", "STATE_ID", "STATE", "POPULATION", "COUNTY_FIPS", "US_LAT_LONG") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# ...

# %%
#testing sql db connection 
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("Resources/data/importexport.db")

cur = con.cursor()

# The result of a "cursor.execute" can be iterated over by row
for row in cur.execute('SELECT * FROM export2019;'):
    print(row)

# Be sure to close the connection
con.close()
