# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# %%
# Census API key
from courtCensusKey import censusKey

# %%
complete_url='https://api.census.gov/data/timeseries/intltrade/imports/hs'+\
            '?get=SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC'+\
            '&I_COMMODITY=3926201010'+\
            '&YEAR=2020'+\
            '&MONTH=*'

# %%
response=requests.get(complete_url)
response
# Out:
# <Response [200]>

# %%
pd.DataFrame(response.json())
# Out:
#                 0             1         2                        3  \
# 0     SUMMARY_LVL  SUMMARY_LVL2  CTY_CODE                 CTY_NAME
# 1             DET            HS         -  TOTAL FOR ALL COUNTRIES
# 2             DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# 3             DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# 4             DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# ...           ...           ...       ...                      ...
# 6334          CGP      HSCYCSDT      5XXX                     ASIA
# 6335          CGP      HSCYCSDT      5XXX                     ASIA
# 6336          CGP      HSCYCSDT      5XXX                     ASIA
# 6337          CGP      HSCYCSDT      5XXX                     ASIA
# 6338          CGP      HSCYCSDT      5XXX                     ASIA
#
#                 4           5           6         7                        8  \
# 0     CTY_SUBCODE  GEN_VAL_MO  GEN_VAL_YR  DISTRICT                DIST_NAME
# 1               -    15511687    15511687         -  TOTAL FOR ALL DISTRICTS
# 2              00      100359      100359        04               BOSTON, MA
# 3              00     2782365     2782365        10        NEW YORK CITY, NY
# 4              00      221603      221603        13            BALTIMORE, MD
# ...           ...         ...         ...       ...                      ...
# 6334           00     1006807     3898670        45            ST. LOUIS, MO
# 6335           00       72900      493236        49             SAN JUAN, PR
# 6336           00      232422     1385480        52                MIAMI, FL
# 6337           00      532575     2537001        53    HOUSTON-GALVESTON, TX
# 6338           00      563946     4949043        55    DALLAS-FORT WORTH, TX
#
#                9          10                                             11  \
# 0     CON_VAL_MO  CON_VAL_YR                              I_COMMODITY_SDESC
# 1       15549907    15549907  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 2         100359      100359  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 3        2782365     2782365  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 4         221603      221603  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# ...          ...         ...                                            ...
# 6334     1006807     3898670  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 6335       72900      493236  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 6336      232422     1385480  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 6337      532575     2537001  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 6338      563946     4949043  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
#
#                12    13     14
# 0     I_COMMODITY  YEAR  MONTH
# 1      3926201010  2020     01
# 2      3926201010  2020     01
# 3      3926201010  2020     01
# 4      3926201010  2020     01
# ...           ...   ...    ...
# 6334   3926201010  2020     12
# 6335   3926201010  2020     12
# 6336   3926201010  2020     12
# 6337   3926201010  2020     12
# 6338   3926201010  2020     12
#
# [6339 rows x 15 columns]

# %%
#Setting variables 
year='2020'
month='*'
cols='SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC'

# %%
#Base URL 
base_url = 'https://api.census.gov/data/timeseries/intltrade/imports/hs'

complete_url = f'{base_url}?get={cols}&YEAR={year}&MONTH={month}'

# HTS Codes and what they represent
# 0901 - Coffee
# 480300 - Toilet Paper
# 2203 - Beer
# 2204 - Wine
# Hard alcohol - 2207

# Items in US top imports
# Pharmaceuticals - $116.3 billion
    # 3002 - Vaccines, Blood, and Immunological products
    # 3003 - Medication (unmeasured doses)
    # 3004 - Medication (measured doses)
    # 3005 - Medically-treated Bandages
    # 3006 - Surgical Equipment
# Medical Equipment - $93.4 billion
# Plastics - $61.9 billion
# Organic chemicals - $54.6 billion

hts_list=['3002','3003','3004','3005','3006']
df_list=[]

for each_hts in hts_list:
    hts_code=each_hts
    query_params={
        'get': 'SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC',
        'I_COMMODITY': hts_code,
        'YEAR': '2020',
        'MONTH': "*"
    }
    import_response=requests.get(base_url, params=query_params)
    #print(max_response.json())
    df_list.append(import_response.json()[1:])
    #print(df_list)

# %%
importList = []
for product in df_list:
    importList += product

# %%
importData2020 = pd.DataFrame(importList, columns=import_response.json()[0])
importData2020
# Out:
#        SUMMARY_LVL SUMMARY_LVL2 CTY_CODE                 CTY_NAME CTY_SUBCODE  \
# 0              DET           HS        -  TOTAL FOR ALL COUNTRIES           -
# 1              CGP         HSCY     0001                     OPEC           -
# 2              CGP         HSCY     0003           EUROPEAN UNION           -
# 3              CGP         HSCY     0014    PACIFIC RIM COUNTRIES           -
# 4              CGP         HSCY     0017                 CAFTA-DR           -
# ...            ...          ...      ...                      ...         ...
# 100570         DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES          MX
# 100571         DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES          MX
# 100572         DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES           S
# 100573         DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES           S
# 100574         DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES           S
#
#         GEN_VAL_MO  GEN_VAL_YR DISTRICT                DIST_NAME  CON_VAL_MO  \
# 0       4266658876  4266658876        -  TOTAL FOR ALL DISTRICTS  4268407445
# 1            57909       57909        -  TOTAL FOR ALL DISTRICTS       57909
# 2       3418406596  3418406596        -  TOTAL FOR ALL DISTRICTS  3420155165
# 3        594809210   594809210        -  TOTAL FOR ALL DISTRICTS   594809210
# 4          1498217     1498217        -  TOTAL FOR ALL DISTRICTS     1498217
# ...            ...         ...      ...                      ...         ...
# 100570           0       45528       23               LAREDO, TX           0
# 100571           0     1213439       25            SAN DIEGO, CA           0
# 100572        9340      172397       09              BUFFALO, NY        9340
# 100573      132869      913871       25            SAN DIEGO, CA      132869
# 100574       76690      446572       38              DETROIT, MI       76690
#
#         CON_VAL_YR                             I_COMMODITY_SDESC I_COMMODITY  \
# 0       4268407445                      HUMAN BLOOD; ANIMAL BLOO        3002
# 1            57909                      HUMAN BLOOD; ANIMAL BLOO        3002
# 2       3420155165                      HUMAN BLOOD; ANIMAL BLOO        3002
# 3        594809210                      HUMAN BLOOD; ANIMAL BLOO        3002
# 4          1498217                      HUMAN BLOOD; ANIMAL BLOO        3002
# ...            ...                                           ...         ...
# 100570       45528  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 100571     1213439  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 100572      172397  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 100573      913871  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 100574      446572  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
#
#         YEAR MONTH
# 0       2020    01
# 1       2020    01
# 2       2020    01
# 3       2020    01
# 4       2020    01
# ...      ...   ...
# 100570  2020    12
# 100571  2020    12
# 100572  2020    12
# 100573  2020    12
# 100574  2020    12
#
# [100575 rows x 15 columns]

# %%
importData2020['I_COMMODITY_SDESC'].unique()
# Out:
# array(['HUMAN BLOOD; ANIMAL BLOO', 'MEDICAMENTS NESOI OF MIXTU',
#        'MEDICAMENTS NESOI, MIXED O', 'BANDAGES ETC COATED ETC OR',
#        'PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30'], dtype=object)

# %%
importData2020 = importData2020.rename(columns={                                            
    "SUMMARY_LVL": "SUMMARY_LEVEL", "SUMMARY_LVL2": "SUMMARY_LEVEL_2", 
    "CTY_CODE": "COUNTRY_CODE", "CTY_NAME": "COUNTRY_NAME", "CTY_SUBCODE": "COUNTRY_SUBCODE",
    "GEN_VAL_MO": "GENERAL_VALUES_MONTH", "GEN_VAL_YR": "GENERAL_VALUES_YEAR",
    "DIST_NAME": "DISTRICT_NAME", "CON_VAL_MO": "MONTHLY_CONSUMPTION_VALUE", 
    "CON_VAL_YR": "YEARLY_CONSUMPTION_VALUE", "I_COMMODITY_SDESC": "COMMODITY_DESCRIPTION", 
    "I_COMMODITY": "COMMODITY"})

# %%
# Clean up commodity names
importData2020.loc[(importData2020.COMMODITY_DESCRIPTION == 'HUMAN BLOOD; ANIMAL BLOO'), 'COMMODITY_DESCRIPTION'] = 'Vaccines, Blood, and Immunological products'
importData2020.loc[(importData2020.COMMODITY_DESCRIPTION == 'MEDICAMENTS NESOI OF MIXTU'), 'COMMODITY_DESCRIPTION'] = 'Medication (unmeasured doses)'
importData2020.loc[(importData2020.COMMODITY_DESCRIPTION == 'MEDICAMENTS NESOI, MIXED O'), 'COMMODITY_DESCRIPTION'] = 'Medication (measured doses)'
importData2020.loc[(importData2020.COMMODITY_DESCRIPTION == 'BANDAGES ETC COATED ETC OR'), 'COMMODITY_DESCRIPTION'] = 'Medically-Treated Bandages'
importData2020.loc[(importData2020.COMMODITY_DESCRIPTION == 'PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30'), 'COMMODITY_DESCRIPTION'] = 'Surgical Equipment'
importData2020
# Out:
#        SUMMARY_LEVEL SUMMARY_LEVEL_2 COUNTRY_CODE             COUNTRY_NAME  \
# 0                DET              HS            -  TOTAL FOR ALL COUNTRIES
# 1                CGP            HSCY         0001                     OPEC
# 2                CGP            HSCY         0003           EUROPEAN UNION
# 3                CGP            HSCY         0014    PACIFIC RIM COUNTRIES
# 4                CGP            HSCY         0017                 CAFTA-DR
# ...              ...             ...          ...                      ...
# 100570           DET          HSCSDT            -  TOTAL FOR ALL COUNTRIES
# 100571           DET          HSCSDT            -  TOTAL FOR ALL COUNTRIES
# 100572           DET          HSCSDT            -  TOTAL FOR ALL COUNTRIES
# 100573           DET          HSCSDT            -  TOTAL FOR ALL COUNTRIES
# 100574           DET          HSCSDT            -  TOTAL FOR ALL COUNTRIES
#
#        COUNTRY_SUBCODE GENERAL_VALUES_MONTH GENERAL_VALUES_YEAR DISTRICT  \
# 0                    -           4266658876          4266658876        -
# 1                    -                57909               57909        -
# 2                    -           3418406596          3418406596        -
# 3                    -            594809210           594809210        -
# 4                    -              1498217             1498217        -
# ...                ...                  ...                 ...      ...
# 100570              MX                    0               45528       23
# 100571              MX                    0             1213439       25
# 100572               S                 9340              172397       09
# 100573               S               132869              913871       25
# 100574               S                76690              446572       38
#
#                   DISTRICT_NAME MONTHLY_CONSUMPTION_VALUE  \
# 0       TOTAL FOR ALL DISTRICTS                4268407445
# 1       TOTAL FOR ALL DISTRICTS                     57909
# 2       TOTAL FOR ALL DISTRICTS                3420155165
# 3       TOTAL FOR ALL DISTRICTS                 594809210
# 4       TOTAL FOR ALL DISTRICTS                   1498217
# ...                         ...                       ...
# 100570               LAREDO, TX                         0
# 100571            SAN DIEGO, CA                         0
# 100572              BUFFALO, NY                      9340
# 100573            SAN DIEGO, CA                    132869
# 100574              DETROIT, MI                     76690
#
#        YEARLY_CONSUMPTION_VALUE                        COMMODITY_DESCRIPTION  \
# 0                    4268407445  Vaccines, Blood, and Immunological products
# 1                         57909  Vaccines, Blood, and Immunological products
# 2                    3420155165  Vaccines, Blood, and Immunological products
# 3                     594809210  Vaccines, Blood, and Immunological products
# 4                       1498217  Vaccines, Blood, and Immunological products
# ...                         ...                                          ...
# 100570                    45528                           Surgical Equipment
# 100571                  1213439                           Surgical Equipment
# 100572                   172397                           Surgical Equipment
# 100573                   913871                           Surgical Equipment
# 100574                   446572                           Surgical Equipment
#
#        COMMODITY  YEAR MONTH
# 0           3002  2020    01
# 1           3002  2020    01
# 2           3002  2020    01
# 3           3002  2020    01
# 4           3002  2020    01
# ...          ...   ...   ...
# 100570      3006  2020    12
# 100571      3006  2020    12
# 100572      3006  2020    12
# 100573      3006  2020    12
# 100574      3006  2020    12
#
# [100575 rows x 15 columns]

# %%
# Create table with only totals for visualization
totalImportData2020 = importData2020[(importData2020['COUNTRY_NAME'] == "TOTAL FOR ALL COUNTRIES") & (importData2020['DISTRICT_NAME'] == "TOTAL FOR ALL DISTRICTS")]

# drop aggregated totals
importData2020= importData2020[importData2020['CTY_NAME']!="TOTAL FOR ALL COUNTRIES"]
importData2020= importData2020[importData2020['DIST_NAME']!="TOTAL FOR ALL DISTRICTS"]
importData2020
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CTY_NAME'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-e5f25ae2f5c6> in <module>
#       3
#       4 # drop aggregated totals
# ----> 5 importData2020= importData2020[importData2020['CTY_NAME']!="TOTAL FOR ALL COUNTRIES"]
#       6 importData2020= importData2020[importData2020['DIST_NAME']!="TOTAL FOR ALL DISTRICTS"]
#       7 importData2020
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CTY_NAME'

# %%
# Save as a csv
# Using encoding="utf-8" to avoid issues later
importData2020.to_csv("Resources/importData2020.csv", encoding="utf-8", index=False)
totalImportData2020.to_csv("Resources/totalImportData2020.csv", encoding="utf-8", index=False)
