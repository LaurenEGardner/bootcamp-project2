# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# %%
# Census API key
from courtCensusKey import censusKey

# %%
complete_url='https://api.census.gov/data/timeseries/intltrade/imports/hs'+\
            '?get=SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC'+\
            '&I_COMMODITY=3926201010'+\
            '&YEAR=2020'+\
            '&MONTH=*'

# %%
response=requests.get(complete_url)
response
# Out:
# <Response [200]>

# %%
pd.DataFrame(response.json())
# Out:
#                 0             1         2                        3  \
# 0     SUMMARY_LVL  SUMMARY_LVL2  CTY_CODE                 CTY_NAME
# 1             DET            HS         -  TOTAL FOR ALL COUNTRIES
# 2             DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# 3             DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# 4             DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# ...           ...           ...       ...                      ...
# 5684          DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# 5685          DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# 5686          DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# 5687          DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# 5688          DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
#
#                 4           5           6         7                        8  \
# 0     CTY_SUBCODE  GEN_VAL_MO  GEN_VAL_YR  DISTRICT                DIST_NAME
# 1               -    15511687    15511687         -  TOTAL FOR ALL DISTRICTS
# 2              00      100359      100359        04               BOSTON, MA
# 3              00     2782365     2782365        10        NEW YORK CITY, NY
# 4              00      221603      221603        13            BALTIMORE, MD
# ...           ...         ...         ...       ...                      ...
# 5684           00      528218     2891863        45            ST. LOUIS, MO
# 5685           00           0      420336        49             SAN JUAN, PR
# 5686           00      375335     1155445        52                MIAMI, FL
# 5687           00      135000     2004426        53    HOUSTON-GALVESTON, TX
# 5688           00     1199603     4385097        55    DALLAS-FORT WORTH, TX
#
#                9          10                                             11  \
# 0     CON_VAL_MO  CON_VAL_YR                              I_COMMODITY_SDESC
# 1       15549907    15549907  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 2         100359      100359  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 3        2782365     2782365  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 4         221603      221603  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# ...          ...         ...                                            ...
# 5684      528218     2891863  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 5685           0      420336  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 5686      375335     1155445  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 5687      135000     2004426  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 5688     1199603     4385097  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
#
#                12    13     14
# 0     I_COMMODITY  YEAR  MONTH
# 1      3926201010  2020     01
# 2      3926201010  2020     01
# 3      3926201010  2020     01
# 4      3926201010  2020     01
# ...           ...   ...    ...
# 5684   3926201010  2020     11
# 5685   3926201010  2020     11
# 5686   3926201010  2020     11
# 5687   3926201010  2020     11
# 5688   3926201010  2020     11
#
# [5689 rows x 15 columns]

# %%
#Setting variables 
year='2020'
month='*'
cols='SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC'

# %%
#Base URL 
base_url = 'https://api.census.gov/data/timeseries/intltrade/imports/hs'

complete_url = f'{base_url}?get={cols}&YEAR={year}&MONTH={month}'


hts_list=['3926201010','4015110110']
df_list=[]

for each_hts in hts_list:
    hts_code=each_hts
    query_params={
        'get': 'SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC',
        'I_COMMODITY': hts_code,
        'YEAR': '2020',
        'MONTH': "*"
    }
    import_response=requests.get(base_url, params=query_params)
    #print(max_response.json())
    df_list.append(import_response.json()[1:])
    #print(df_list)

# %%
importList = []
for product in df_list:
    importList += product

# %%
importData2020 = pd.DataFrame(importList, columns=import_response.json()[0])
importData2020
# Out:
#      SUMMARY_LVL SUMMARY_LVL2 CTY_CODE                 CTY_NAME CTY_SUBCODE  \
# 0            DET           HS        -  TOTAL FOR ALL COUNTRIES           -
# 1            DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES          00
# 2            DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES          00
# 3            DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES          00
# 4            DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES          00
# ...          ...          ...      ...                      ...         ...
# 9745         CGP     HSCYCSDT     5XXX                     ASIA          00
# 9746         CGP     HSCYCSDT     5XXX                     ASIA          00
# 9747         CGP     HSCYCSDT     5XXX                     ASIA          00
# 9748         CGP     HSCYCSDT     5XXX                     ASIA          00
# 9749         CGP     HSCYCSDT     5XXX                     ASIA          00
#
#      GEN_VAL_MO GEN_VAL_YR DISTRICT                DIST_NAME CON_VAL_MO  \
# 0      15511687   15511687        -  TOTAL FOR ALL DISTRICTS   15549907
# 1        100359     100359       04               BOSTON, MA     100359
# 2       2782365    2782365       10        NEW YORK CITY, NY    2782365
# 3        221603     221603       13            BALTIMORE, MD     221603
# 4        407135     407135       16           CHARLESTON, SC     407135
# ...         ...        ...      ...                      ...        ...
# 9745          0      32161       38              DETROIT, MI          0
# 9746     542291    5127337       39              CHICAGO, IL     542291
# 9747       1200      14944       41            CLEVELAND, OH       1200
# 9748     239644    2034506       45            ST. LOUIS, MO     239644
# 9749          0     279005       55    DALLAS-FORT WORTH, TX          0
#
#      CON_VAL_YR                              I_COMMODITY_SDESC I_COMMODITY  \
# 0      15549907  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC  3926201010
# 1        100359  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC  3926201010
# 2       2782365  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC  3926201010
# 3        221603  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC  3926201010
# 4        407135  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC  3926201010
# ...         ...                                            ...         ...
# 9745      32161              SURGICAL GLOVES OF NATURAL RUBBER  4015110110
# 9746    5127337              SURGICAL GLOVES OF NATURAL RUBBER  4015110110
# 9747      14944              SURGICAL GLOVES OF NATURAL RUBBER  4015110110
# 9748    2034506              SURGICAL GLOVES OF NATURAL RUBBER  4015110110
# 9749     279005              SURGICAL GLOVES OF NATURAL RUBBER  4015110110
#
#       YEAR MONTH
# 0     2020    01
# 1     2020    01
# 2     2020    01
# 3     2020    01
# 4     2020    01
# ...    ...   ...
# 9745  2020    11
# 9746  2020    11
# 9747  2020    11
# 9748  2020    11
# 9749  2020    11
#
# [9750 rows x 15 columns]

# %%
importData2020['I_COMMODITY_SDESC'].unique()
# Out:
# array(['GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC',
#        'SURGICAL GLOVES OF NATURAL RUBBER'], dtype=object)

# %%
importData2020 = importData2020.rename(columns={"SUMMARY_LVL": "SUMMARY LEVEL", "SUMMARY_LVL2": "SUMMARY LEVEL 2", "CTY_CODE": "COUNTRY CODE", "CTY_NAME": "COUNTRY NAME", "CTY_SUBCODE": "COUNTRY SUBCODE", "GEN_VAL_MO": "GENERAL VALUES/MONTH", "GEN_VAL_YR": "GENERAL VALUES/YEAR", "DIST_NAME": "DISTRICT NAME", "CON_VAL_MO": "MONTHLY CONSUMPTION VALUE", "CON_VAL_YR": "YEARLY CONSUMPTION VALUE", "I_COMMODITY_SDESC": "COMMODITY DESCRIPTION", "I_COMMODITY": "COMMODITY"})
importData2020
# Out:
#      SUMMARY LEVEL SUMMARY LEVEL 2 COUNTRY CODE             COUNTRY NAME  \
# 0              DET              HS            -  TOTAL FOR ALL COUNTRIES
# 1              DET          HSCSDT            -  TOTAL FOR ALL COUNTRIES
# 2              DET          HSCSDT            -  TOTAL FOR ALL COUNTRIES
# 3              DET          HSCSDT            -  TOTAL FOR ALL COUNTRIES
# 4              DET          HSCSDT            -  TOTAL FOR ALL COUNTRIES
# ...            ...             ...          ...                      ...
# 9745           CGP        HSCYCSDT         5XXX                     ASIA
# 9746           CGP        HSCYCSDT         5XXX                     ASIA
# 9747           CGP        HSCYCSDT         5XXX                     ASIA
# 9748           CGP        HSCYCSDT         5XXX                     ASIA
# 9749           CGP        HSCYCSDT         5XXX                     ASIA
#
#      COUNTRY SUBCODE GENERAL VALUES/MONTH GENERAL VALUES/YEAR DISTRICT  \
# 0                  -             15511687            15511687        -
# 1                 00               100359              100359       04
# 2                 00              2782365             2782365       10
# 3                 00               221603              221603       13
# 4                 00               407135              407135       16
# ...              ...                  ...                 ...      ...
# 9745              00                    0               32161       38
# 9746              00               542291             5127337       39
# 9747              00                 1200               14944       41
# 9748              00               239644             2034506       45
# 9749              00                    0              279005       55
#
#                 DISTRICT NAME MONTHLY CONSUMPTION VALUE  \
# 0     TOTAL FOR ALL DISTRICTS                  15549907
# 1                  BOSTON, MA                    100359
# 2           NEW YORK CITY, NY                   2782365
# 3               BALTIMORE, MD                    221603
# 4              CHARLESTON, SC                    407135
# ...                       ...                       ...
# 9745              DETROIT, MI                         0
# 9746              CHICAGO, IL                    542291
# 9747            CLEVELAND, OH                      1200
# 9748            ST. LOUIS, MO                    239644
# 9749    DALLAS-FORT WORTH, TX                         0
#
#      YEARLY CONSUMPTION VALUE                          COMMODITY DESCRIPTION  \
# 0                    15549907  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 1                      100359  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 2                     2782365  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 3                      221603  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 4                      407135  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# ...                       ...                                            ...
# 9745                    32161              SURGICAL GLOVES OF NATURAL RUBBER
# 9746                  5127337              SURGICAL GLOVES OF NATURAL RUBBER
# 9747                    14944              SURGICAL GLOVES OF NATURAL RUBBER
# 9748                  2034506              SURGICAL GLOVES OF NATURAL RUBBER
# 9749                   279005              SURGICAL GLOVES OF NATURAL RUBBER
#
#        COMMODITY  YEAR MONTH
# 0     3926201010  2020    01
# 1     3926201010  2020    01
# 2     3926201010  2020    01
# 3     3926201010  2020    01
# 4     3926201010  2020    01
# ...          ...   ...   ...
# 9745  4015110110  2020    11
# 9746  4015110110  2020    11
# 9747  4015110110  2020    11
# 9748  4015110110  2020    11
# 9749  4015110110  2020    11
#
# [9750 rows x 15 columns]

# %%
# Save as a csv
# Using encoding="utf-8" to avoid issues later
importData2020.to_csv("Resources/importData2020.csv", encoding="utf-8", index=False)
