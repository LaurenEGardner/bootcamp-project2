# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# %%
# Census API key
from courtCensusKey import censusKey

# %%
complete_url='https://api.census.gov/data/timeseries/intltrade/imports/hs'+\
            '?get=SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC'+\
            '&I_COMMODITY=0901'+\
            '&YEAR=2019'+\
            '&MONTH=*'

# %%
response=requests.get(complete_url)
response
# Out:
# <Response [200]>

# %%
pd.DataFrame(response.json())
# Out:
#                  0             1         2                        3  \
# 0      SUMMARY_LVL  SUMMARY_LVL2  CTY_CODE                 CTY_NAME
# 1              DET            HS         -  TOTAL FOR ALL COUNTRIES
# 2              DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# 3              DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# 4              DET        HSCSDT         -  TOTAL FOR ALL COUNTRIES
# ...            ...           ...       ...                      ...
# 32208          CGP        HSCYDT      7XXX                   AFRICA
# 32209          CGP        HSCYDT      7XXX                   AFRICA
# 32210          CGP        HSCYDT      7XXX                   AFRICA
# 32211          CGP        HSCYDT      7XXX                   AFRICA
# 32212          CGP        HSCYDT      7XXX                   AFRICA
#
#                  4           5           6         7                        8  \
# 0      CTY_SUBCODE  GEN_VAL_MO  GEN_VAL_YR  DISTRICT                DIST_NAME
# 1                -   469013980   469013980         -  TOTAL FOR ALL DISTRICTS
# 2               00      408288      408288        02           ST. ALBANS, VT
# 3               00      115136      115136        04               BOSTON, MA
# 4               00     2904493     2904493        07           OGDENSBURG, NY
# ...            ...         ...         ...       ...                      ...
# 32208            -           0       54340        45            ST. LOUIS, MO
# 32209            -       64262      892937        52                MIAMI, FL
# 32210            -     1273940    10709584        53    HOUSTON-GALVESTON, TX
# 32211            -           0       61841        54           WASHINGTON, DC
# 32212            -           0       25771        55    DALLAS-FORT WORTH, TX
#
#                 9          10  \
# 0      CON_VAL_MO  CON_VAL_YR
# 1       469121228   469121228
# 2          408288      408288
# 3          115136      115136
# 4         2904493     2904493
# ...           ...         ...
# 32208           0       54340
# 32209       64262      892937
# 32210     1273940    10709584
# 32211           0       61841
# 32212           0       25771
#
#                                                       11           12    13  \
# 0                                      I_COMMODITY_SDESC  I_COMMODITY  YEAR
# 1      COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE         0901  2019
# 2      COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE         0901  2019
# 3      COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE         0901  2019
# 4      COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE         0901  2019
# ...                                                  ...          ...   ...
# 32208  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE         0901  2019
# 32209  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE         0901  2019
# 32210  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE         0901  2019
# 32211  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE         0901  2019
# 32212  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE         0901  2019
#
#           14
# 0      MONTH
# 1         01
# 2         01
# 3         01
# 4         01
# ...      ...
# 32208     12
# 32209     12
# 32210     12
# 32211     12
# 32212     12
#
# [32213 rows x 15 columns]

# %%
#Setting variables 
year='2019'
month='*'
cols='SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC'

# %%
#Base URL 
base_url = 'https://api.census.gov/data/timeseries/intltrade/imports/hs'

complete_url = f'{base_url}?get={cols}&YEAR={year}&MONTH={month}'

# HTC Codes and what they represent
# 0901 - Coffee
# 480300 - Toilet Paper
# 2203 - Beer
# 2204 - Wine
# Hard alcohol - 2207

# Items in US top imports
# Pharmaceuticals - $116.3 billion
    # 3002 - Vaccines, Blood, and Immunological products
    # 3003 - Medication (unmeasured doses)
    # 3004 - Medication (measured doses)
    # 3005 - Medically-treated Bandages
    # 3006 - Surgical Equipment
# Medical Equipment - $93.4 billion
# Plastics - $61.9 billion
# Organic chemicals - $54.6 billion

hts_list=['3006']
df_list=[]

for each_hts in hts_list:
    hts_code=each_hts
    query_params={
        'get': 'SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC',
        'I_COMMODITY': hts_code,
        'YEAR': '2019',
        'MONTH': "*"
    }
    import_response=requests.get(base_url, params=query_params)
    #print(max_response.json())
    df_list.append(import_response.json()[1:])
    #print(df_list)

# %%
importList = []
for product in df_list:
    importList += product

# %%
importData = pd.DataFrame(importList, columns=import_response.json()[0])
importData
# Out:
#       SUMMARY_LVL SUMMARY_LVL2 CTY_CODE                 CTY_NAME CTY_SUBCODE  \
# 0             DET           HS        -  TOTAL FOR ALL COUNTRIES           -
# 1             DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES          00
# 2             DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES          00
# 3             DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES          00
# 4             DET       HSCSDT        -  TOTAL FOR ALL COUNTRIES          00
# ...           ...          ...      ...                      ...         ...
# 18852         CGP     HSCYCSDT     6XXX    AUSTRALIA AND OCEANIA          00
# 18853         CGP     HSCYCSDT     6XXX    AUSTRALIA AND OCEANIA          00
# 18854         CGP     HSCYCSDT     6XXX    AUSTRALIA AND OCEANIA          00
# 18855         DET     HSCYCSDT     7800               SEYCHELLES          00
# 18856         CGP     HSCYCSDT     7XXX                   AFRICA          00
#
#       GEN_VAL_MO GEN_VAL_YR DISTRICT                DIST_NAME CON_VAL_MO  \
# 0      418435243  418435243        -  TOTAL FOR ALL DISTRICTS  417983938
# 1        2197465    2197465       04               BOSTON, MA    2197465
# 2      181549423  181549423       07           OGDENSBURG, NY  181549423
# 3       11404872   11404872       09              BUFFALO, NY   11404872
# 4       53975415   53975415       10        NEW YORK CITY, NY   53975415
# ...          ...        ...      ...                      ...        ...
# 18852          0       6122       41            CLEVELAND, OH          0
# 18853          0      61890       49             SAN JUAN, PR          0
# 18854      15191      24877       52                MIAMI, FL      15191
# 18855          0       9426       10        NEW YORK CITY, NY          0
# 18856          0       9426       10        NEW YORK CITY, NY          0
#
#       CON_VAL_YR                             I_COMMODITY_SDESC I_COMMODITY  \
# 0      417983938  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 1        2197465  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 2      181549423  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 3       11404872  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 4       53975415  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# ...          ...                                           ...         ...
# 18852       6122  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 18853      61890  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 18854      24877  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 18855       9426  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
# 18856       9426  PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30        3006
#
#        YEAR MONTH
# 0      2019    01
# 1      2019    01
# 2      2019    01
# 3      2019    01
# 4      2019    01
# ...     ...   ...
# 18852  2019    12
# 18853  2019    12
# 18854  2019    12
# 18855  2019    12
# 18856  2019    12
#
# [18857 rows x 15 columns]

# %%
# drop aggregated totals
importData= importData[importData['CTY_NAME']!="TOTAL FOR ALL COUNTRIES"]
importData= importData[importData['DIST_NAME']!="TOTAL FOR ALL DISTRICTS"]
importData
# Out:
#       SUMMARY_LVL SUMMARY_LVL2 CTY_CODE        CTY_NAME CTY_SUBCODE  \
# 211           CGP       HSCYDT     0003  EUROPEAN UNION           -
# 213           CGP       HSCYDT     0001            OPEC           -
# 214           CGP       HSCYDT     0001            OPEC           -
# 215           CGP       HSCYDT     0001            OPEC           -
# 216           CGP       HSCYDT     0001            OPEC           -
# ...           ...          ...      ...             ...         ...
# 32207         CGP       HSCYDT     7XXX          AFRICA           -
# 32208         CGP       HSCYDT     7XXX          AFRICA           -
# 32209         CGP       HSCYDT     7XXX          AFRICA           -
# 32210         CGP       HSCYDT     7XXX          AFRICA           -
# 32211         CGP       HSCYDT     7XXX          AFRICA           -
#
#       GEN_VAL_MO GEN_VAL_YR DISTRICT              DIST_NAME CON_VAL_MO  \
# 211       115136     115136       04             BOSTON, MA     115136
# 213        20201      20201       10      NEW YORK CITY, NY      20201
# 214       130038     130038       28      SAN FRANCISCO, CA     130038
# 215        15255      15255       52              MIAMI, FL      15255
# 216        33025      33025       53  HOUSTON-GALVESTON, TX      33025
# ...          ...        ...      ...                    ...        ...
# 32207          0      54340       45          ST. LOUIS, MO          0
# 32208      64262     892937       52              MIAMI, FL      64262
# 32209    1273940   10709584       53  HOUSTON-GALVESTON, TX    1273940
# 32210          0      61841       54         WASHINGTON, DC          0
# 32211          0      25771       55  DALLAS-FORT WORTH, TX          0
#
#       CON_VAL_YR                                  I_COMMODITY_SDESC  \
# 211       115136  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE
# 213        20201  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE
# 214       130038  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE
# 215        15255  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE
# 216        33025  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE
# ...          ...                                                ...
# 32207      54340  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE
# 32208     892937  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE
# 32209   10709584  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE
# 32210      61841  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE
# 32211      25771  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE
#
#       I_COMMODITY  YEAR MONTH
# 211          0901  2019    01
# 213          0901  2019    01
# 214          0901  2019    01
# 215          0901  2019    01
# 216          0901  2019    01
# ...           ...   ...   ...
# 32207        0901  2019    12
# 32208        0901  2019    12
# 32209        0901  2019    12
# 32210        0901  2019    12
# 32211        0901  2019    12
#
# [28381 rows x 15 columns]

# %%
importData['I_COMMODITY_SDESC'].unique()
# Out:
# array(['PHARMACEUTICAL GOODS IN NOTE 4 TO CHAPTER 30'], dtype=object)

# %%
importData.columns
# Out:
# Index(['SUMMARY_LVL', 'SUMMARY_LVL2', 'CTY_CODE', 'CTY_NAME', 'CTY_SUBCODE',
#        'GEN_VAL_MO', 'GEN_VAL_YR', 'DISTRICT', 'DIST_NAME', 'CON_VAL_MO',
#        'CON_VAL_YR', 'I_COMMODITY_SDESC', 'I_COMMODITY', 'YEAR', 'MONTH'],
#       dtype='object')

# %%
importData = importData.rename(columns={
    "SUMMARY_LVL": "SUMMARY_LEVEL", "SUMMARY_LVL2": "SUMMARY_LEVEL_2", 
    "CTY_CODE": "COUNTRY_CODE", "CTY_NAME": "COUNTRY_NAME", "CTY_SUBCODE": "COUNTRY_SUBCODE",
    "GEN_VAL_MO": "GENERAL_VALUES_MONTH", "GEN_VAL_YR": "GENERAL_VALUES_YEAR",
    "DIST_NAME": "DISTRICT_NAME", "CON_VAL_MO": "MONTHLY_CONSUMPTION_VALUE", 
    "CON_VAL_YR": "YEARLY_CONSUMPTION_VALUE", "I_COMMODITY_SDESC": "COMMODITY_DESCRIPTION", 
    "I_COMMODITY": "COMMODITY"})
importData
# Out:
#       SUMMARY_LEVEL SUMMARY_LEVEL_2 COUNTRY_CODE    COUNTRY_NAME  \
# 211             CGP          HSCYDT         0003  EUROPEAN UNION
# 213             CGP          HSCYDT         0001            OPEC
# 214             CGP          HSCYDT         0001            OPEC
# 215             CGP          HSCYDT         0001            OPEC
# 216             CGP          HSCYDT         0001            OPEC
# ...             ...             ...          ...             ...
# 32207           CGP          HSCYDT         7XXX          AFRICA
# 32208           CGP          HSCYDT         7XXX          AFRICA
# 32209           CGP          HSCYDT         7XXX          AFRICA
# 32210           CGP          HSCYDT         7XXX          AFRICA
# 32211           CGP          HSCYDT         7XXX          AFRICA
#
#       COUNTRY_SUBCODE GENERAL_VALUES_MONTH GENERAL_VALUES_YEAR DISTRICT  \
# 211                 -               115136              115136       04
# 213                 -                20201               20201       10
# 214                 -               130038              130038       28
# 215                 -                15255               15255       52
# 216                 -                33025               33025       53
# ...               ...                  ...                 ...      ...
# 32207               -                    0               54340       45
# 32208               -                64262              892937       52
# 32209               -              1273940            10709584       53
# 32210               -                    0               61841       54
# 32211               -                    0               25771       55
#
#                DISTRICT_NAME MONTHLY_CONSUMPTION_VALUE  \
# 211               BOSTON, MA                    115136
# 213        NEW YORK CITY, NY                     20201
# 214        SAN FRANCISCO, CA                    130038
# 215                MIAMI, FL                     15255
# 216    HOUSTON-GALVESTON, TX                     33025
# ...                      ...                       ...
# 32207          ST. LOUIS, MO                         0
# 32208              MIAMI, FL                     64262
# 32209  HOUSTON-GALVESTON, TX                   1273940
# 32210         WASHINGTON, DC                         0
# 32211  DALLAS-FORT WORTH, TX                         0
#
#       YEARLY_CONSUMPTION_VALUE  \
# 211                     115136
# 213                      20201
# 214                     130038
# 215                      15255
# 216                      33025
# ...                        ...
# 32207                    54340
# 32208                   892937
# 32209                 10709584
# 32210                    61841
# 32211                    25771
#
#                                    COMMODITY_DESCRIPTION COMMODITY  YEAR MONTH
# 211    COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE      0901  2019    01
# 213    COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE      0901  2019    01
# 214    COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE      0901  2019    01
# 215    COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE      0901  2019    01
# 216    COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE      0901  2019    01
# ...                                                  ...       ...   ...   ...
# 32207  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE      0901  2019    12
# 32208  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE      0901  2019    12
# 32209  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE      0901  2019    12
# 32210  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE      0901  2019    12
# 32211  COFFEE; COFFEE HUSKS ETC; SUBSTITUTES WITH COFFEE      0901  2019    12
#
# [28381 rows x 15 columns]

# %%
# Save as a csv
# Using encoding="utf-8" to avoid issues later
importData.to_csv("Resources/importData2019.csv", encoding="utf-8", index=False)
