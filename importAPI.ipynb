# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# Census API key
from courtCensusKey import censusKey
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-2cf4e7d9dee8> in <module>
#       4 import matplotlib.pyplot as plt
#       5 import requests
# ----> 6 from census import Census
#       7
#       8 # Census API key
#
# ModuleNotFoundError: No module named 'census'

# %%
import_url='https://api.census.gov/data/timeseries/intltrade/imports/hs'+\
            '?get=DISTRICT,DIST_NAME,CTY_CODE,CTY_NAME,CTY_SUBCODE,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC'+\
            '&I_COMMODITY=4015110110'+\
            '&YEAR=2019'+\
            '&MONTH=*'

# %%
SurgicalGloves=requests.get(import_url)
SurgicalGloves
# Out:
# <Response [200]>

# %%
pd.DataFrame(SurgicalGloves.json())
# Out:
#             0                        1         2   \
# 0     DISTRICT                DIST_NAME  CTY_CODE
# 1            -  TOTAL FOR ALL DISTRICTS         -
# 2            -  TOTAL FOR ALL DISTRICTS      0014
# 3            -  TOTAL FOR ALL DISTRICTS      0020
# 4            -  TOTAL FOR ALL DISTRICTS      0021
# ...        ...                      ...       ...
# 4282        45            ST. LOUIS, MO         -
# 4283        52                MIAMI, FL         -
# 4284        53    HOUSTON-GALVESTON, TX         -
# 4285        54           WASHINGTON, DC         -
# 4286        55    DALLAS-FORT WORTH, TX         -
#
#                                    3            4           5           6   \
# 0                            CTY_NAME  CTY_SUBCODE  CON_VAL_MO  CON_VAL_YR
# 1             TOTAL FOR ALL COUNTRIES            -     6469678     6469678
# 2               PACIFIC RIM COUNTRIES            -     3769691     3769691
# ...

# %%
#Setting variables 
year='2019'
month='*'
cols='DISTRICT,DIST_NAME,CITY_NAME,ALL_VAL_MO,ALL_VAL_YR,E_COMMODITY_SDESC'

# %%
#Base URL 
base_url = 'https://api.census.gov/data/timeseries/intltrade/exports/hs'

complete_url = f'{base_url}?get={cols}&YEAR={year}&MONTH={month}'


hts_list=['2926100000','4002510000','4002590000','2836500000','4002110000','3904100000']
df_list=[]

for each_hts in hts_list:
    hts_code=each_hts
    query_params={
        'get': 'DISTRICT,DIST_NAME,CITY_NAME,ALL_VAL_MO,ALL_VAL_YR,E_COMMODITY_SDESC',
        'E_COMMODITY': hts_code,
        'YEAR': '2019',
        'MONTH': "*"
    }
    max_response=requests.get(base_url, params=query_params)
    #print(max_response.json())
    df_list.append(max_response.json()[1:])
#print(df_list)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-30-f1b96a5e018d> in <module>
#      18     max_response=requests.get(base_url, params=query_params)
#      19     #print(max_response.json())
# ---> 20     df_list.append(max_response.json()[1:])
#      21 #print(df_list)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
# ...

# %%
importData = pd.DataFrame(max_response.json())
importData

# %%
importData['E_COMMODITY_SDESC'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-306a6ae24814> in <module>
# ----> 1 importData['E_COMMODITY_SDESC'].unique()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     347                 except ValueError as err:
#     348                     raise KeyError(key) from err
# --> 349             raise KeyError(key)
#     350         return super().get_loc(key, method=method, tolerance=tolerance)
# ...

# %%
#Retrieve Data
response=requests.get(data_url)
print(response.text)
