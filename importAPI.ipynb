# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# %%
# Census API key
from courtCensusKey import censusKey

# %%
complete_url='https://api.census.gov/data/timeseries/intltrade/imports/hs'+\
            '?get=SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC'+\
            '&I_COMMODITY=3926201010'+\
            '&YEAR=2019'+\
            '&MONTH=*'

# %%
response=requests.get(complete_url)
response
# Out:
# <Response [200]>

# %%
pd.DataFrame(response.json())
# Out:
#                0             1         2                        3   \
# 0     SUMMARY_LVL  SUMMARY_LVL2  CTY_CODE                 CTY_NAME
# 1             DET            HS         -  TOTAL FOR ALL COUNTRIES
# 2             CGP          HSCY      0003           EUROPEAN UNION
# 3             CGP          HSCY      0014    PACIFIC RIM COUNTRIES
# 4             CGP          HSCY      0020                    NAFTA
# ...           ...           ...       ...                      ...
# 5758          DET          HSDT         -  TOTAL FOR ALL COUNTRIES
# 5759          DET          HSDT         -  TOTAL FOR ALL COUNTRIES
# 5760          DET          HSDT         -  TOTAL FOR ALL COUNTRIES
# 5761          DET          HSDT         -  TOTAL FOR ALL COUNTRIES
# 5762          DET          HSDT         -  TOTAL FOR ALL COUNTRIES
#
#                4           5           6         7                        8   \
# 0     CTY_SUBCODE  GEN_VAL_MO  GEN_VAL_YR  DISTRICT                DIST_NAME
# 1               -    16961897    16961897         -  TOTAL FOR ALL DISTRICTS
# 2               -       86406       86406         -  TOTAL FOR ALL DISTRICTS
# 3               -    16786273    16786273         -  TOTAL FOR ALL DISTRICTS
# 4               -         373         373         -  TOTAL FOR ALL DISTRICTS
# ...           ...         ...         ...       ...                      ...
# 5758            -      158596     1716506        45            ST. LOUIS, MO
# 5759            -        5967      343248        49             SAN JUAN, PR
# 5760            -        5280     1034804        52                MIAMI, FL
# 5761            -      208849     1445274        55    DALLAS-FORT WORTH, TX
# 5762            -      129669      920547        53    HOUSTON-GALVESTON, TX
#
#               9           10                                             11  \
# 0     CON_VAL_MO  CON_VAL_YR                              I_COMMODITY_SDESC
# 1       16961897    16961897  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 2          86406       86406  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 3       16786273    16786273  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 4            373         373  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# ...          ...         ...                                            ...
# 5758      158596     1716506  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 5759        5967      343248  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 5760        5280     1034804  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 5761      208849     1445274  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 5762      129669      920547  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
#
#                12    13     14
# 0     I_COMMODITY  YEAR  MONTH
# 1      3926201010  2019     01
# 2      3926201010  2019     01
# 3      3926201010  2019     01
# 4      3926201010  2019     01
# ...           ...   ...    ...
# 5758   3926201010  2019     12
# 5759   3926201010  2019     12
# 5760   3926201010  2019     12
# 5761   3926201010  2019     12
# 5762   3926201010  2019     12
#
# [5763 rows x 15 columns]

# %%
#Setting variables 
year='2019'
month='*'
cols='SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC'

# %%
#Base URL 
base_url = 'https://api.census.gov/data/timeseries/intltrade/imports/hs'

complete_url = f'{base_url}?get={cols}&YEAR={year}&MONTH={month}'


hts_list=['3926201010','4015110110']
df_list=[]

for each_hts in hts_list:
    hts_code=each_hts
    query_params={
        'get': 'SUMMARY_LVL,SUMMARY_LVL2,CTY_CODE,CTY_NAME,CTY_SUBCODE,GEN_VAL_MO,GEN_VAL_YR,DISTRICT,DIST_NAME,CON_VAL_MO,CON_VAL_YR,I_COMMODITY_SDESC',
        'I_COMMODITY': hts_code,
        'YEAR': '2019',
        'MONTH': "*"
    }
    import_response=requests.get(base_url, params=query_params)
    #print(max_response.json())
    df_list.append(import_response.json()[1:])
    #print(df_list)

# %%
importList = []
for product in df_list:
    importList += product

# %%
importData = pd.DataFrame(importList, columns=import_response.json()[0])
importData
# Out:
#       SUMMARY_LVL SUMMARY_LVL2 CTY_CODE                         CTY_NAME  \
# 0             DET           HS        -          TOTAL FOR ALL COUNTRIES
# 1             CGP         HSCY     0003                   EUROPEAN UNION
# 2             CGP         HSCY     0014            PACIFIC RIM COUNTRIES
# 3             CGP         HSCY     0020                            NAFTA
# 4             CGP         HSCY     0021  TWENTY LATIN AMERICAN REPUBLICS
# ...           ...          ...      ...                              ...
# 10043         DET       HSCSDT        -          TOTAL FOR ALL COUNTRIES
# 10044         DET       HSCSDT        -          TOTAL FOR ALL COUNTRIES
# 10045         DET       HSCSDT        -          TOTAL FOR ALL COUNTRIES
# 10046         DET       HSCSDT        -          TOTAL FOR ALL COUNTRIES
# 10047         DET       HSCSDT        -          TOTAL FOR ALL COUNTRIES
#
#       CTY_SUBCODE GEN_VAL_MO GEN_VAL_YR DISTRICT                DIST_NAME  \
# 0               -   16961897   16961897        -  TOTAL FOR ALL DISTRICTS
# 1               -      86406      86406        -  TOTAL FOR ALL DISTRICTS
# 2               -   16786273   16786273        -  TOTAL FOR ALL DISTRICTS
# 3               -        373        373        -  TOTAL FOR ALL DISTRICTS
# 4               -        373        373        -  TOTAL FOR ALL DISTRICTS
# ...           ...        ...        ...      ...                      ...
# 10043          00          0     111785       45            ST. LOUIS, MO
# 10044          00          0     119177       52                MIAMI, FL
# 10045          00          0       1130       53    HOUSTON-GALVESTON, TX
# 10046          00          0      13800       54           WASHINGTON, DC
# 10047          00      82775     405460       55    DALLAS-FORT WORTH, TX
#
#       CON_VAL_MO CON_VAL_YR                              I_COMMODITY_SDESC  \
# 0       16961897   16961897  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 1          86406      86406  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 2       16786273   16786273  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 3            373        373  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 4            373        373  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# ...          ...        ...                                            ...
# 10043          0     111785              SURGICAL GLOVES OF NATURAL RUBBER
# 10044          0     119177              SURGICAL GLOVES OF NATURAL RUBBER
# 10045          0       1130              SURGICAL GLOVES OF NATURAL RUBBER
# 10046          0      13800              SURGICAL GLOVES OF NATURAL RUBBER
# 10047      82775     405460              SURGICAL GLOVES OF NATURAL RUBBER
#
#       I_COMMODITY  YEAR MONTH
# 0      3926201010  2019    01
# 1      3926201010  2019    01
# 2      3926201010  2019    01
# 3      3926201010  2019    01
# 4      3926201010  2019    01
# ...           ...   ...   ...
# 10043  4015110110  2019    12
# 10044  4015110110  2019    12
# 10045  4015110110  2019    12
# 10046  4015110110  2019    12
# 10047  4015110110  2019    12
#
# [10048 rows x 15 columns]

# %%
# drop aggregated totals
importData= importData[importData['CTY_NAME']!="TOTAL FOR ALL COUNTRIES"]
importData= importData[importData['DIST_NAME']!="TOTAL FOR ALL DISTRICTS"]
importData
# Out:
#       SUMMARY_LVL SUMMARY_LVL2 CTY_CODE               CTY_NAME CTY_SUBCODE  \
# 69            CGP     HSCYCSDT     0003         EUROPEAN UNION          00
# 70            CGP     HSCYCSDT     0014  PACIFIC RIM COUNTRIES          00
# 71            CGP     HSCYCSDT     0014  PACIFIC RIM COUNTRIES          00
# 72            CGP     HSCYCSDT     0014  PACIFIC RIM COUNTRIES          00
# 73            CGP     HSCYCSDT     0014  PACIFIC RIM COUNTRIES          00
# ...           ...          ...      ...                    ...         ...
# 10018         CGP       HSCYDT     5XXX                   ASIA           -
# 10019         CGP       HSCYDT     5XXX                   ASIA           -
# 10021         CGP       HSCYDT     5XXX                   ASIA           -
# 10022         CGP       HSCYDT     5XXX                   ASIA           -
# 10023         CGP       HSCYDT     5XXX                   ASIA           -
#
#       GEN_VAL_MO GEN_VAL_YR DISTRICT              DIST_NAME CON_VAL_MO  \
# 69         86406      86406       41          CLEVELAND, OH      86406
# 70        268698     268698       04             BOSTON, MA     268698
# 71           336        336       07         OGDENSBURG, NY        336
# 72           790        790       09            BUFFALO, NY        790
# 73       3801253    3801253       10      NEW YORK CITY, NY    3801253
# ...          ...        ...      ...                    ...        ...
# 10018          0     380560       41          CLEVELAND, OH          0
# 10019          0     111785       45          ST. LOUIS, MO          0
# 10021          0       1130       53  HOUSTON-GALVESTON, TX          0
# 10022          0      13800       54         WASHINGTON, DC          0
# 10023      82775     405460       55  DALLAS-FORT WORTH, TX      82775
#
#       CON_VAL_YR                              I_COMMODITY_SDESC I_COMMODITY  \
# 69         86406  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC  3926201010
# 70        268698  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC  3926201010
# 71           336  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC  3926201010
# 72           790  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC  3926201010
# 73       3801253  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC  3926201010
# ...          ...                                            ...         ...
# 10018     380560              SURGICAL GLOVES OF NATURAL RUBBER  4015110110
# 10019     111785              SURGICAL GLOVES OF NATURAL RUBBER  4015110110
# 10021       1130              SURGICAL GLOVES OF NATURAL RUBBER  4015110110
# 10022      13800              SURGICAL GLOVES OF NATURAL RUBBER  4015110110
# 10023     405460              SURGICAL GLOVES OF NATURAL RUBBER  4015110110
#
#        YEAR MONTH
# 69     2019    01
# 70     2019    01
# 71     2019    01
# 72     2019    01
# 73     2019    01
# ...     ...   ...
# 10018  2019    12
# 10019  2019    12
# 10021  2019    12
# 10022  2019    12
# 10023  2019    12
#
# [7698 rows x 15 columns]

# %%
importData['I_COMMODITY_SDESC'].unique()
# Out:
# array(['GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC',
#        'SURGICAL GLOVES OF NATURAL RUBBER'], dtype=object)

# %%
importData.columns
# Out:
# Index(['SUMMARY_LVL', 'SUMMARY_LVL2', 'CTY_CODE', 'CTY_NAME', 'CTY_SUBCODE',
#        'GEN_VAL_MO', 'GEN_VAL_YR', 'DISTRICT', 'DIST_NAME', 'CON_VAL_MO',
#        'CON_VAL_YR', 'I_COMMODITY_SDESC', 'I_COMMODITY', 'YEAR', 'MONTH'],
#       dtype='object')

# %%
importData = importData.rename(columns={
    "SUMMARY_LVL": "SUMMARY_LEVEL", "SUMMARY_LVL2": "SUMMARY_LEVEL_2", 
    "CTY_CODE": "COUNTRY_CODE", "CTY_NAME": "COUNTRY_NAME", "CTY_SUBCODE": "COUNTRY_SUBCODE",
    "GEN_VAL_MO": "GENERAL_VALUES_MONTH", "GEN_VAL_YR": "GENERAL_VALUES_YEAR",
    "DIST_NAME": "DISTRICT_NAME", "CON_VAL_MO": "MONTHLY_CONSUMPTION_VALUE", 
    "CON_VAL_YR": "YEARLY_CONSUMPTION_VALUE", "I_COMMODITY_SDESC": "COMMODITY_DESCRIPTION", 
    "I_COMMODITY": "COMMODITY"})
importData
# Out:
#       SUMMARY_LEVEL SUMMARY_LEVEL_2 COUNTRY_CODE           COUNTRY_NAME  \
# 69              CGP        HSCYCSDT         0003         EUROPEAN UNION
# 70              CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
# 71              CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
# 72              CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
# 73              CGP        HSCYCSDT         0014  PACIFIC RIM COUNTRIES
# ...             ...             ...          ...                    ...
# 10018           CGP          HSCYDT         5XXX                   ASIA
# 10019           CGP          HSCYDT         5XXX                   ASIA
# 10021           CGP          HSCYDT         5XXX                   ASIA
# 10022           CGP          HSCYDT         5XXX                   ASIA
# 10023           CGP          HSCYDT         5XXX                   ASIA
#
#       COUNTRY_SUBCODE GENERAL_VALUES_MONTH GENERAL_VALUES_YEAR DISTRICT  \
# 69                 00                86406               86406       41
# 70                 00               268698              268698       04
# 71                 00                  336                 336       07
# 72                 00                  790                 790       09
# 73                 00              3801253             3801253       10
# ...               ...                  ...                 ...      ...
# 10018               -                    0              380560       41
# 10019               -                    0              111785       45
# 10021               -                    0                1130       53
# 10022               -                    0               13800       54
# 10023               -                82775              405460       55
#
#                DISTRICT_NAME MONTHLY_CONSUMPTION_VALUE  \
# 69             CLEVELAND, OH                     86406
# 70                BOSTON, MA                    268698
# 71            OGDENSBURG, NY                       336
# 72               BUFFALO, NY                       790
# 73         NEW YORK CITY, NY                   3801253
# ...                      ...                       ...
# 10018          CLEVELAND, OH                         0
# 10019          ST. LOUIS, MO                         0
# 10021  HOUSTON-GALVESTON, TX                         0
# 10022         WASHINGTON, DC                         0
# 10023  DALLAS-FORT WORTH, TX                     82775
#
#       YEARLY_CONSUMPTION_VALUE                          COMMODITY_DESCRIPTION  \
# 69                       86406  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 70                      268698  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 71                         336  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 72                         790  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# 73                     3801253  GLOVES,SEAMLESS,SURGICAL & MEDICAL,OF PLASTIC
# ...                        ...                                            ...
# 10018                   380560              SURGICAL GLOVES OF NATURAL RUBBER
# 10019                   111785              SURGICAL GLOVES OF NATURAL RUBBER
# 10021                     1130              SURGICAL GLOVES OF NATURAL RUBBER
# 10022                    13800              SURGICAL GLOVES OF NATURAL RUBBER
# 10023                   405460              SURGICAL GLOVES OF NATURAL RUBBER
#
#         COMMODITY  YEAR MONTH
# 69     3926201010  2019    01
# 70     3926201010  2019    01
# 71     3926201010  2019    01
# 72     3926201010  2019    01
# 73     3926201010  2019    01
# ...           ...   ...   ...
# 10018  4015110110  2019    12
# 10019  4015110110  2019    12
# 10021  4015110110  2019    12
# 10022  4015110110  2019    12
# 10023  4015110110  2019    12
#
# [7698 rows x 15 columns]

# %%
# Save as a csv
# Using encoding="utf-8" to avoid issues later
importData.to_csv("Resources/importData2019.csv", encoding="utf-8", index=False)
